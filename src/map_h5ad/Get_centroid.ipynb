# %%
from cgitb import small

import numpy as np
import scanpy as sc
import pandas as pd
# Out:
# C:\Users\Orangeeee\AppData\Local\Temp\ipykernel_10044\3797874725.py:1: DeprecationWarning: 'cgitb' is deprecated and slated for removal in Python 3.13
#   from cgitb import small

# %%
bladder_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\bladder_ref.h5ad"
knee_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\knee_ref.h5ad"
large_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\large_intestine_ref.h5ad"
lymph_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\lymph_node_ref.h5ad"
small_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\small_intestine_ref.h5ad"
spleen_path = r"E:\UIC_PHD\Python_projects\parquet_read\src\map_h5ad\refs\spleen_ref.h5ad"

# %%
bladder = sc.read_h5ad(bladder_path)
knee = sc.read_h5ad(knee_path)
large = sc.read_h5ad(large_path)
lymph = sc.read_h5ad(lymph_path)
small = sc.read_h5ad(small_path)
spleen = sc.read_h5ad(spleen_path)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bladder = sc.read_h5ad(bladder_path)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:284, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     281         return read_dataframe(elem)
#     282     return func(elem)
# --> 284 adata = read_dispatched(f, callback=callback)
#     286 # Backwards compat (should figure out which version)
#     287 if "raw.X" in f:
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:266, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
# --> 266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
#     269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:269, in <dictcomp>(.0)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
# --> 269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:282, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     279 elif elem_name in {"/obs", "/var"}:
#     280     # Backwards compat
#     281     return read_dataframe(elem)
# --> 282 return func(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\methods.py:881, in read_sparse(elem, _reader)
#     876 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     877 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     878 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     879 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     880 def read_sparse(elem: GroupStorageType, *, _reader: Reader) -> CSMatrix | CSArray:
# --> 881     return sparse_dataset(elem).to_memory()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_core\sparse_dataset.py:655, in BaseCompressedSparseDataset.to_memory(self)
#     651 format_class = get_memory_class(
#     652     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     653 )
#     654 mtx = format_class(self.shape, dtype=self.dtype)
# --> 655 mtx.data = self._data[...]
#     656 mtx.indices = self._indices[...]
#     657 mtx.indptr = self._indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\h5py\_hl\dataset.py:840, in Dataset.__getitem__(self, args, new_dtype)
#     838 if self._fast_read_ok and (new_dtype is None):
#     839     try:
# --> 840         return self._fast_reader.read(args)
#     841     except TypeError:
#     842         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:367, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:341, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 989. MiB for an array with shape (259205043,) and data type float32
# Error raised while reading key 'X' of <class 'h5py._hl.group.Group'> from /

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 knee = sc.read_h5ad(knee_path)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:284, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     281         return read_dataframe(elem)
#     282     return func(elem)
# --> 284 adata = read_dispatched(f, callback=callback)
#     286 # Backwards compat (should figure out which version)
#     287 if "raw.X" in f:
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:266, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
# --> 266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
#     269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:269, in <dictcomp>(.0)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
# --> 269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:282, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     279 elif elem_name in {"/obs", "/var"}:
#     280     # Backwards compat
#     281     return read_dataframe(elem)
# --> 282 return func(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\methods.py:881, in read_sparse(elem, _reader)
#     876 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     877 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     878 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     879 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     880 def read_sparse(elem: GroupStorageType, *, _reader: Reader) -> CSMatrix | CSArray:
# --> 881     return sparse_dataset(elem).to_memory()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_core\sparse_dataset.py:656, in BaseCompressedSparseDataset.to_memory(self)
#     654 mtx = format_class(self.shape, dtype=self.dtype)
#     655 mtx.data = self._data[...]
# --> 656 mtx.indices = self._indices[...]
#     657 mtx.indptr = self._indptr
#     658 return mtx
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\h5py\_hl\dataset.py:840, in Dataset.__getitem__(self, args, new_dtype)
#     838 if self._fast_read_ok and (new_dtype is None):
#     839     try:
# --> 840         return self._fast_reader.read(args)
#     841     except TypeError:
#     842         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:367, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:341, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 2.22 GiB for an array with shape (298412427,) and data type int64
# Error raised while reading key 'X' of <class 'h5py._hl.group.Group'> from /

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 large = sc.read_h5ad(large_path)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:284, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     281         return read_dataframe(elem)
#     282     return func(elem)
# --> 284 adata = read_dispatched(f, callback=callback)
#     286 # Backwards compat (should figure out which version)
#     287 if "raw.X" in f:
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:266, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
# --> 266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
#     269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:269, in <dictcomp>(.0)
#     264 def callback(func, elem_name: str, elem, iospec):
#     265     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     266         return AnnData(**{
#     267             # This is covering up backwards compat in the anndata initializer
#     268             # In most cases we should be able to call `func(elen[k])` instead
# --> 269             k: read_dispatched(elem[k], callback)
#     270             for k in elem
#     271             if not k.startswith("raw.")
#     272         })
#     273     elif elem_name.startswith("/raw."):
#     274         return None
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:282, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     279 elif elem_name in {"/obs", "/var"}:
#     280     # Backwards compat
#     281     return read_dataframe(elem)
# --> 282 return func(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\methods.py:379, in read_mapping(elem, _reader)
#     376 @_REGISTRY.register_read(H5Group, IOSpec("dict", "0.1.0"))
#     377 @_REGISTRY.register_read(ZarrGroup, IOSpec("dict", "0.1.0"))
#     378 def read_mapping(elem: GroupStorageType, *, _reader: Reader) -> dict[str, AxisStorable]:
# --> 379     return {k: _reader.read_elem(v) for k, v in dict(elem).items()}
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\methods.py:379, in <dictcomp>(.0)
#     376 @_REGISTRY.register_read(H5Group, IOSpec("dict", "0.1.0"))
#     377 @_REGISTRY.register_read(ZarrGroup, IOSpec("dict", "0.1.0"))
#     378 def read_mapping(elem: GroupStorageType, *, _reader: Reader) -> dict[str, AxisStorable]:
# --> 379     return {k: _reader.read_elem(v) for k, v in dict(elem).items()}
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\utils.py:205, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     203     raise ValueError(msg)
#     204 try:
# --> 205     return func(*args, **kwargs)
#     206 except Exception as e:
#     207     path, key = _get_display_path(store).rsplit("/", 1)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\registry.py:286, in Reader.read_elem(self, elem, modifiers)
#     284 if self.callback is None:
#     285     return read_func(elem)
# --> 286 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\h5ad.py:282, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     279 elif elem_name in {"/obs", "/var"}:
#     280     # Backwards compat
#     281     return read_dataframe(elem)
# --> 282 return func(elem)
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_io\specs\methods.py:881, in read_sparse(elem, _reader)
#     876 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     877 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     878 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     879 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     880 def read_sparse(elem: GroupStorageType, *, _reader: Reader) -> CSMatrix | CSArray:
# --> 881     return sparse_dataset(elem).to_memory()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\anndata\_core\sparse_dataset.py:655, in BaseCompressedSparseDataset.to_memory(self)
#     651 format_class = get_memory_class(
#     652     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     653 )
#     654 mtx = format_class(self.shape, dtype=self.dtype)
# --> 655 mtx.data = self._data[...]
#     656 mtx.indices = self._indices[...]
#     657 mtx.indptr = self._indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File E:\UIC_PHD\Python_projects\parquet_read\.venv\Lib\site-packages\h5py\_hl\dataset.py:840, in Dataset.__getitem__(self, args, new_dtype)
#     838 if self._fast_read_ok and (new_dtype is None):
#     839     try:
# --> 840         return self._fast_reader.read(args)
#     841     except TypeError:
#     842         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:367, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:341, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 290. MiB for an array with shape (76117747,) and data type int32
# Error raised while reading key 'decontXcounts' of <class 'h5py._hl.group.Group'> from /layers
